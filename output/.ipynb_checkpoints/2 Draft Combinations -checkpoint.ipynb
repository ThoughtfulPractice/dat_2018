# %%
#import libraries 
import pandas as pd 
import numpy as np
import itertools as it

# %%
df = pd.read_csv('drafts.csv') #import drafts file 
df = df[df.pick == True] #drop false picks
df = df.drop(['extra_time', 'order', 'player_slot', 'total_time_taken', 'pick'], axis=1) #drop unnecessary columns

# %%
heroes_df = pd.read_csv('basic_heroes.csv') #import heroes file
heroes_df = heroes_df [['id','localized_name']].set_index('id')
heroes_dict=heroes_df.to_dict() #create dctionary of heroes
heroes_dict = heroes_dict['localized_name']

# %%
df = df.replace({"hero_id": heroes_dict}) #replace hero_id with hero names

# %%
match_list = set(df.match_id.tolist()) #list all unique match IDs

# %%
teams = (2,3) #list all unique team_id

# %%
complete_combi_list = list()

for match in match_list: #iterate over each match and each team to get combi list of heros used
    for team in teams:
        filtered = df[(df.match_id == match) & (df.active_team == team)]
        hero_list = filtered.hero_id.values.tolist()
        combi_list = list(it.combinations(hero_list,2))
        complete_combi_list.extend(combi_list)

# %%
complete_combi_list2 = [list(elem) for elem in complete_combi_list] #convert list of tuples to list of lists

# %%
#sort lists within list 
for i in complete_combi_list2: 
    i.sort()

# %%
df2 = pd.Series(complete_combi_list2, name = 'combi').astype(str).reset_index() #convert 
df2.columns= ['count','combination']
df2 = df2.groupby(['combination']).count().sort_values('count')

# %%
df2 
df2.to_csv('combinations.csv')

# %%
df2
# Out:
#                                      count
# combination
# ['Ember Spirit', 'Lina']                 1
# ['Io', 'Underlord']                      1
# ['Io', 'Spectre']                        1
# ['Io', 'Pugna']                          1
# ['Io', 'Phantom Lancer']                 1
# ['Io', 'Oracle']                         1
# ['Io', 'Ogre Magi']                      1
# ['Io', 'Leshrac']                        1
# ['Invoker', 'Wraith King']               1
# ['Invoker', 'Winter Wyvern']             1
# ['Invoker', 'Weaver']                    1
# ['Invoker', 'Ursa']                      1
# ['Invoker', 'Underlord']                 1
# ['Invoker', 'Treant Protector']          1
# ['Invoker', 'Silencer']                  1
# ['Io', 'Ursa']                           1
# ['Invoker', 'Phoenix']                   1
# ['Invoker', 'Magnus']                    1
# ['Invoker', 'Lina']                      1
# ['Invoker', "Nature's Prophet"]          1
# ['Huskar', 'Witch Doctor']               1
# ['Huskar', 'Winter Wyvern']              1
# ['Huskar', 'Weaver']                     1
# ['Huskar', 'Tiny']                       1
# ['Huskar', 'Oracle']                     1
# ['Gyrocopter', 'Wraith King']            1
# ['Gyrocopter', 'Weaver']                 1
# ['Gyrocopter', 'Venomancer']             1
# ['Gyrocopter', 'Ursa']                   1
# ['Gyrocopter', 'Underlord']              1
# ...                                    ...
# ['Clinkz', 'Vengeful Spirit']            3
# ['Bane', 'Ursa']                         3
# ['Gyrocopter', 'Undying']                3
# ['Gyrocopter', 'Tiny']                   3
# ['Phantom Lancer', 'Winter Wyvern']      3
# ['Drow Ranger', 'Weaver']                3
# ['Lina', 'Phantom Lancer']               3
# ['Dark Willow', 'Lich']                  3
# ['Alchemist', 'Ursa']                    3
# ['Storm Spirit', 'Vengeful Spirit']      3
# ['Arc Warden', 'Silencer']               3
# ['Phantom Lancer', 'Tiny']               4
# ['Lina', 'Silencer']                     4
# ['Enchantress', 'Gyrocopter']            4
# ['Clinkz', 'Silencer']                   4
# ['Vengeful Spirit', 'Weaver']            4
# ['Chen', 'Phantom Lancer']               4
# ['Ursa', 'Vengeful Spirit']              4
# ['Phoenix', 'Ursa']                      5
# ['Earthshaker', 'Enchantress']           5
# ['Bane', 'Tiny']                         5
# ['Alchemist', 'Vengeful Spirit']         5
# ['Silencer', 'Terrorblade']              5
# ['Necrophos', 'Tiny']                    5
# ['Bane', 'Mirana']                       5
# ['Chen', 'Lina']                         5
# ['Phoenix', 'Vengeful Spirit']           5
# ['Gyrocopter', 'Io']                     6
# ['Dark Willow', 'Wraith King']           7
# ['Earthshaker', 'Silencer']              8
#
# [658 rows x 1 columns]

# %%
test = pd.DataFrame(
    df2.reset_index()['combination'].str.split(",").tolist(),columns=['hero1','hero2']).replace()
test['hero1'].str.replace("[","")
# Out:
# 0         'Ember Spirit'
# 1                   'Io'
# 2                   'Io'
# 3                   'Io'
# 4                   'Io'
# 5                   'Io'
# 6                   'Io'
# 7                   'Io'
# 8              'Invoker'
# 9              'Invoker'
# 10             'Invoker'
# 11             'Invoker'
# 12             'Invoker'
# 13             'Invoker'
# 14             'Invoker'
# 15                  'Io'
# 16             'Invoker'
# 17             'Invoker'
# 18             'Invoker'
# 19             'Invoker'
# 20              'Huskar'
# 21              'Huskar'
# 22              'Huskar'
# 23              'Huskar'
# 24              'Huskar'
# 25          'Gyrocopter'
# 26          'Gyrocopter'
# 27          'Gyrocopter'
# 28          'Gyrocopter'
# 29          'Gyrocopter'
#              ...
# 628             'Clinkz'
# 629               'Bane'
# 630         'Gyrocopter'
# 631         'Gyrocopter'
# 632     'Phantom Lancer'
# 633        'Drow Ranger'
# 634               'Lina'
# 635        'Dark Willow'
# 636          'Alchemist'
# 637       'Storm Spirit'
# 638         'Arc Warden'
# 639     'Phantom Lancer'
# 640               'Lina'
# 641        'Enchantress'
# 642             'Clinkz'
# 643    'Vengeful Spirit'
# 644               'Chen'
# 645               'Ursa'
# 646            'Phoenix'
# 647        'Earthshaker'
# 648               'Bane'
# 649          'Alchemist'
# 650           'Silencer'
# 651          'Necrophos'
# 652               'Bane'
# 653               'Chen'
# 654            'Phoenix'
# 655         'Gyrocopter'
# 656        'Dark Willow'
# 657        'Earthshaker'
# Name: hero1, Length: 658, dtype: object
